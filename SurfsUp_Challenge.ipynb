# %%
# Dependencies
import numpy as np
import pandas as pd
import datetime as dt
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect

# %%
engine = create_engine("sqlite:///hawaii.sqlite")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
Measurement
# Out:
# sqlalchemy.ext.automap.measurement

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
#Get all the column s in the table

connection = engine.connect()
data = connection.execute("SELECT * FROM measurement")
data.keys()
# Out:
# RMKeyView(['id', 'station', 'date', 'prcp', 'tobs'])

# %%
# inspector = inspect(engine)
# columns = inspector.get_columns('measurement')
# columns

# %% [markdown]
# ## D1: Determine the Summary Statistics for June

# %%
# Import the sqlalchemy extract function.
from sqlalchemy import extract
month = "06"
# 1. Write a query that filters the Measurement table to retrieve the temperatures for the month of June. 
June = []
# June = session.query(Measurement.date, Measurement.tobs).filter(func.strftime("%m",Measurement.date)== month)
June= session.query(Measurement.date, Measurement.tobs).filter(extract("month", Measurement.date) == 6)

June_list = [temp.tobs for temp in June]
June_list
# Out:
# [78.0,
#  76.0,
#  78.0,
#  76.0,
#  77.0,
#  78.0,
#  77.0,
#  78.0,
#  78.0,
#  79.0,
#  78.0,
#  78.0,
#  78.0,
#  77.0,
#  78.0,
#  78.0,
#  77.0,
#  77.0,
#  82.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  77.0,
#  76.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  77.0,
#  78.0,
#  73.0,
#  70.0,
#  76.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  78.0,
#  77.0,
#  77.0,
#  78.0,
#  78.0,
#  77.0,
#  78.0,
#  78.0,
#  75.0,
#  76.0,
#  76.0,
#  77.0,
#  78.0,
#  76.0,
#  77.0,
#  75.0,
#  77.0,
#  76.0,
#  76.0,
#  75.0,
#  77.0,
#  77.0,
#  76.0,
#  78.0,
#  77.0,
#  76.0,
#  77.0,
#  76.0,
#  76.0,
#  77.0,
#  77.0,
#  78.0,
#  77.0,
#  77.0,
#  77.0,
#  76.0,
#  75.0,
#  76.0,
#  76.0,
#  77.0,
#  76.0,
#  73.0,
#  73.0,
#  75.0,
#  77.0,
#  76.0,
#  77.0,
#  79.0,
#  78.0,
#  79.0,
#  78.0,
#  78.0,
#  79.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  78.0,
#  77.0,
#  76.0,
#  78.0,
#  78.0,
#  77.0,
#  78.0,
#  78.0,
#  73.0,
#  76.0,
#  77.0,
#  75.0,
#  76.0,
#  74.0,
# ...

# %%
# 2. Convert the June temperatures to a list.
June = list(June_list)
June
# Out:
# [78.0,
#  76.0,
#  78.0,
#  76.0,
#  77.0,
#  78.0,
#  77.0,
#  78.0,
#  78.0,
#  79.0,
#  78.0,
#  78.0,
#  78.0,
#  77.0,
#  78.0,
#  78.0,
#  77.0,
#  77.0,
#  82.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  77.0,
#  76.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  77.0,
#  78.0,
#  73.0,
#  70.0,
#  76.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  78.0,
#  77.0,
#  77.0,
#  78.0,
#  78.0,
#  77.0,
#  78.0,
#  78.0,
#  75.0,
#  76.0,
#  76.0,
#  77.0,
#  78.0,
#  76.0,
#  77.0,
#  75.0,
#  77.0,
#  76.0,
#  76.0,
#  75.0,
#  77.0,
#  77.0,
#  76.0,
#  78.0,
#  77.0,
#  76.0,
#  77.0,
#  76.0,
#  76.0,
#  77.0,
#  77.0,
#  78.0,
#  77.0,
#  77.0,
#  77.0,
#  76.0,
#  75.0,
#  76.0,
#  76.0,
#  77.0,
#  76.0,
#  73.0,
#  73.0,
#  75.0,
#  77.0,
#  76.0,
#  77.0,
#  79.0,
#  78.0,
#  79.0,
#  78.0,
#  78.0,
#  79.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  78.0,
#  77.0,
#  76.0,
#  78.0,
#  78.0,
#  77.0,
#  78.0,
#  78.0,
#  73.0,
#  76.0,
#  77.0,
#  75.0,
#  76.0,
#  74.0,
# ...

# %%
# 3. Create a DataFrame from the list of temperatures for the month of June. 
# June_df = pd.DataFrame(June, columns=['Date','Temperature'])
# June_df.set_index(June_df['Date'], inplace=True)
# June_df

June_df = pd.DataFrame(June_list, columns=['Temperature'])
June_df.head()
# Out:
#    Temperature
# 0         78.0
# 1         76.0
# 2         78.0
# 3         76.0
# 4         77.0

# %%
# 4. Calculate and print out the summary statistics for the June temperature DataFrame.
June_df.describe()
# Out:
#        Temperature
# count  1700.000000
# mean     74.944118
# std       3.257417
# min      64.000000
# 25%      73.000000
# 50%      75.000000
# 75%      77.000000
# max      85.000000

# %%
# 5. Return to your challenge instructions to compare your summary statistics

# %% [markdown]
# ## D2: Determine the Summary Statistics for December

# %%
# 6. Write a query that filters the Measurement table to retrieve the temperatures for the month of December.
month = "12"
# 1. Write a query that filters the Measurement table to retrieve the temperatures for the month of June. 
Dec = []
Dec = session.query(Measurement.date, Measurement.tobs).filter(func.strftime("%m",Measurement.date)== month)

# %%
# 7. Convert the December temperatures to a list.
Dec= list(Dec)

# %%
# 8. Create a DataFrame from the list of temperatures for the month of December. 
Dec_df = pd.DataFrame(Dec, columns=['Date','Temperature'])
Dec_df.set_index(Dec_df['Date'], inplace=True)
Dec_df
# Out:
#                   Date  Temperature
# Date
# 2010-12-01  2010-12-01         76.0
# 2010-12-03  2010-12-03         74.0
# 2010-12-04  2010-12-04         74.0
# 2010-12-06  2010-12-06         64.0
# 2010-12-07  2010-12-07         64.0
# ...                ...          ...
# 2016-12-27  2016-12-27         71.0
# 2016-12-28  2016-12-28         71.0
# 2016-12-29  2016-12-29         69.0
# 2016-12-30  2016-12-30         65.0
# 2016-12-31  2016-12-31         65.0
#
# [1517 rows x 2 columns]

# %%
# 9. Calculate and print out the summary statistics for the Decemeber temperature DataFrame.
Dec_df.describe()
# Out:
#        Temperature
# count  1517.000000
# mean     71.041529
# std       3.745920
# min      56.000000
# 25%      69.000000
# 50%      71.000000
# 75%      74.000000
# max      83.000000

# %%
# 10. Return to your challenge instructions to compare your summary statistics
